# %%
# %pylab inline
import pandas as pd
import re
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.rcParams['font.sans-serif']=['SimHei']

# %%
df = pd.read_csv('lianjia0407.csv')

# %%
def extract_info(s, pattern):
    result = re.findall(pattern, s)
    if len(result) > 0:
        return result[0]
    else:
        return np.nan

# %%
df['unitPrice'] = df.apply(lambda row: extract_info(row['houseUnitPrice'], pattern=r'\d+'), axis=1)
df['halls'] = df.apply(lambda row: extract_info(row['houseInfo'], pattern=r'\d(?=厅)'), axis=1)
df['areas'] = df.apply(lambda row: extract_info(row['houseInfo'], pattern=r'(\d+\.\d+|\d+)(?=平米)'), axis=1)
df['followers'] = df.apply(lambda row: extract_info(row['houseFollowInfo'], pattern=r'\d+(?=人关注)'), axis=1)
df['rooms'] = df.apply(lambda row: extract_info(row['houseInfo'], pattern=r'\d(?=室)'), axis=1)

# %%
df.columns
# Out:
# Index(['title', 'houseLoc', 'houseInfo', 'housePosition', 'housePositionInfo',
#        'houseFollowInfo', 'houseSubway', 'houseTaxfree', 'houseHaskey',
#        'houseTotalPrice', 'housePriceUnit', 'houseUnitPrice', 'houseUrl',
#        'unitPrice', 'halls', 'areas', 'followers', 'rooms'],
#       dtype='object')

# %%
df2 = df.reindex(columns=['title', 'houseLoc', 'unitPrice', 'areas', 'houseTotalPrice', 'housePriceUnit', 
            'houseInfo', 'housePosition', 'housePositionInfo' ,
            'rooms', 'halls', 'followers',
           'houseFollowInfo', 'houseSubway', 'houseTaxfree', 'houseHaskey',
           'houseUnitPrice', 'houseUrl'])

# %%
df2.to_excel('lianjia.xlsx')

# %%
df2.drop('title', axis=1, inplace=True)

# %%
df2.columns
# Out:
# Index(['houseLoc', 'unitPrice', 'areas', 'houseTotalPrice', 'housePriceUnit',
#        'houseInfo', 'housePosition', 'housePositionInfo', 'rooms', 'halls',
#        'followers', 'houseFollowInfo', 'houseSubway', 'houseTaxfree',
#        'houseHaskey', 'houseUnitPrice', 'houseUrl'],
#       dtype='object')

# %%
df2[(df2.houseTotalPrice <= 220) & (df2.houseTotalPrice > 160) & (df2.areas.astype(float) > 70)]['houseLoc'].value_counts()
# Out:
# 威尼斯水城第十五街区     10
# 江岸水城            8
# 东郊小镇第三街区        7
# 天润城第十街区         7
# 天润城第十四街区        7
# 威尼斯水城第十街区       7
# 天华硅谷            6
# 天润城第十六街区南区      6
# 万科金色半山          5
# 威尼斯水城第十四街区      5
# 天华绿谷庄园          5
# 天润城第十二街区        5
# 威尼斯水城第六街区       5
# 翰香苑             5
# 威尼斯水城第五街区       5
# 威尼斯水城第十一街区      5
# 美麟香漫山           4
# 天润城第十一街区        4
# 银城蓝溪郡           4
# 东郊小镇第二街区        4
# 天润城第十六街区北区      4
# 盛和家园            4
# 金地自在城第二街区       3
# 合家春天            3
# 宋都南郡国际北区        3
# 威尼斯水城第十二街区      3
# 幸福美地花园          3
# 万裕龙庭水岸          3
# 南湾营融康苑          3
# 银亿东城第十二街区       3
#                ..
# 招商1872          1
# 华侨绿洲            1
# 阳光之旅            1
# 杜鹃园             1
# 建宁路             1
# 大华锦绣华城乐美颂       1
# 环宇家园            1
# 幕府一村            1
# 威尼斯水城第九街区       1
# 旭日爱上城第四区北区      1
# 长虹新寓            1
# 钱塘望景花园          1
# 明发云庭            1
# 雨花新村四村          1
# 爱达花园兰花园         1
# 凤凰花园            1
# 招商兰溪谷           1
# 鼎业花苑            1
# 南方花园枫彩园         1
# 大华锦绣华城桂美颂       1
# 花港幸福城玫瑰园        1
# 太平花苑南区          1
# 利星公寓            1
# 力标赞城            1
# 定淮门2号           1
# 钓鱼台             1
# 双乐园小区           1
# 建宁路143号         1
# 盛和家园南区          1
# 启迪方洲慧园          1
# Name: houseLoc, Length: 242, dtype: int64

# %%
df2.describe()
# Out:
#        houseTotalPrice
# count      3029.000000
# mean        293.295213
# std         178.295399
# min          12.000000
# 25%         185.000000
# 50%         248.000000
# 75%         349.800000
# max        2700.000000

# %%
df2.loc[(df2.houseTotalPrice < 300) & (df2.housePositionInfo == '仙林'), ('houseLoc', 'unitPrice', 'areas',
                                    'houseTotalPrice', 'housePositionInfo',
                                   'houseUrl')].sort_values(by='areas', ascending=False)
# Out:
#        houseLoc unitPrice  areas  houseTotalPrice housePositionInfo  \
# 106        诚品城      28076  99.02            278.0                仙林
# 193        诚品城      29341  98.84            290.0                仙林
# 2476    保利罗兰春天      30212  95.99            290.0                仙林
# 2675      鸿运嘉园      30527     95            290.0                仙林
# 2901    保利罗兰春天      31183     93            290.0                仙林
# 1280       诚品城      27839   91.6            255.0                仙林
# 344        诚品城      25922  90.66            235.0                仙林
# 52         诚品城      27455  90.33            248.0                仙林
# 2049       诚品城      28889     90            260.0                仙林
# 8       万科金色领域      33230  89.68            298.0                仙林
# 391   南京师范大学茶苑      32289  83.62            270.0                仙林
# 2080    东方天郡西区      36663   79.1            290.0                仙林
# 1456     亚东城西区      34054   78.7            268.0                仙林
# 869       仙林新村      32609     69            225.0                仙林
# 14       亚东城西区      37217   61.8            230.0                仙林
# 2812     亚东城西区      38154  51.11            195.0                仙林
# 1294     赛世香樟园      28701  48.78            140.0                仙林
# 2839      仙林新村      37038   37.8            140.0                仙林
# 1005      仙鹤山庄      44192  31.68            140.0                仙林
# 2784      雁鸣山庄      30996  30.65             95.0                仙林
#
#                                                houseUrl
# 106   https://nj.lianjia.com/ershoufang/103102286517...
# 193   https://nj.lianjia.com/ershoufang/103102283643...
# 2476  https://nj.lianjia.com/ershoufang/103102244929...
# 2675  https://nj.lianjia.com/ershoufang/103102241516...
# 2901  https://nj.lianjia.com/ershoufang/103102237377...
# 1280  https://nj.lianjia.com/ershoufang/103102262775...
# 344   https://nj.lianjia.com/ershoufang/103102279944...
# 52    https://nj.lianjia.com/ershoufang/103102287834...
# 2049  https://nj.lianjia.com/ershoufang/103102251493...
# 8     https://nj.lianjia.com/ershoufang/103102289892...
# 391   https://nj.lianjia.com/ershoufang/103102278974...
# 2080  https://nj.lianjia.com/ershoufang/103102251070...
# 1456  https://nj.lianjia.com/ershoufang/103102259665...
# 869   https://nj.lianjia.com/ershoufang/103102270684...
# 14    https://nj.lianjia.com/ershoufang/103102289128...
# 2812  https://nj.lianjia.com/ershoufang/103102238977...
# 1294  https://nj.lianjia.com/ershoufang/103102262428...
# 2839  https://nj.lianjia.com/ershoufang/103102238558...
# 1005  https://nj.lianjia.com/ershoufang/103102268377...
# 2784  https://nj.lianjia.com/ershoufang/103102239380...

# %%
df2.groupby('housePositionInfo').size().sort_values(ascending=False)
# Out:
# housePositionInfo
# 桥北       272
# 东山镇      222
# 麒麟镇      125
# 百家湖      111
# 岔路口      101
# 江浦街道      92
# 奥体        90
# 龙江        78
# 将军大道      78
# 仙林        74
# 月牙湖       73
# 江宁大学城     65
# 马群        65
# 九龙湖       57
# 洪家园       54
# 秦虹        52
# 迈皋桥       51
# 瑞金路       49
# 凤凰西街      47
# 定淮门大街     43
# 湖南路       40
# 南湖        37
# 新街口       37
# 铁心桥       36
# 应天西路      36
# 大光路       35
# 南苑        34
# 红山        32
# 五老村       31
# 科学园       30
#         ...
# 长江路       17
# 月苑        17
# 草场门大街     17
# 樱驼花园      17
# 珠江路       16
# 卫岗        16
# 孝陵卫       15
# 兴隆大街      13
# 许府巷       12
# 湖西街       12
# 雨花新村      12
# 后宰门       11
# 仙鹤门       11
# 建康路       11
# 挹江门       10
# 长乐路        9
# 万寿         9
# 江宁其它       9
# 安德门        8
# 常府街        8
# 顶山街道       8
# 水佐岗        8
# 江东         6
# 夫子庙        5
# 玄武门        5
# 北京东路       4
# 高新区        2
# 燕子矶        1
# 江心洲        1
# 栖霞其它       1
# Length: 86, dtype: int64

# %%
df.corr()
# Out:
#                  houseTotalPrice
# houseTotalPrice              1.0
